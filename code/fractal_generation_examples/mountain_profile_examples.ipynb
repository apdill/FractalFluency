# %%
import numpy as np
from FF.image_processing import thresh, prepare_scalemap, edgedetector
from FF.fractal_generation import midpoint_displacement, mountainpro

from fracstack import portfolio_plot

# %%
iterations = 11
P = 1
zslice = 0.5

min_size = 16
n_decades = 1.5
max_size = np.ceil(10**(np.log10(min_size)+n_decades))
num_sizes = 50
num_pos = 100

save_dir = r'/home/apd/Projects/FractalFluency/datasets/fractal_portfolio/mountain_profiles'

# %% [markdown]
# ## *Mountain Profile Fractal Portfolio*
#
#
# Below are some examples of generated mountain profile fractals using the midpoint displacement algorithm. I calculate the fractal dimension (D0) using the box-counting method and the information dimension (D1) via Shannon entropy. Results aren't always the same when re-executing cells, but should be within neighborhood of the same value.
#
# Each generated image is 2049x2049 pixels, with analysis spanning 1.5 decades of size from 16 to 506 pixels, which is ~1/4 image size. For each box size, 100 separate offsets are used to determine the measure; for D0, the minimum coverage count from all 100 offsets is used, and for D1, the average entropy of all 100 offsets is used.
#
# ---------------------------------------------------

# %% [markdown]
# ## **D = ~1.1**

# %%
target_D0 = 1.1
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 1

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice, scale_factor=0.3)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1

# %% [markdown]
# ## **D = ~1.2**

# %%
target_D0 = 1.2
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 1

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1
# Out:
# Skipping, d0 = 1.14, r2 = 0.999750

# %% [markdown]
# ## **D = ~1.3**

# %%
target_D0 = 1.3
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 1.1

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1
# Out:
# Skipping, d0 = 1.15, r2 = 0.998895
# Skipping, d0 = 1.23, r2 = 0.999217

# %% [markdown]
# ## **D = ~1.4**

# %%
target_D0 = 1.4
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 1.4

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1
# Out:
# Skipping, d0 = 1.35, r2 = 0.999669

# %% [markdown]
# ## **D = ~1.5**

# %%
target_D0 = 1.5
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 1.6

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1

# %% [markdown]
# ## **D = ~1.6**

# %%
target_D0 = 1.6
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 1.75

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1

# %% [markdown]
# ## **D = ~1.7**

# %%
target_D0 = 1.7
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 1.9

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1
# Out:
# Skipping, d0 = 1.66, r2 = 0.999859
# Skipping, d0 = 1.61, r2 = 0.999798

# %% [markdown]
# ## **D = ~1.8**

# %%
target_D0 = 1.8
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 2.1

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice, scale_factor=1.5)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1
# Out:
# Skipping, d0 = 1.75, r2 = 0.999630

# %% [markdown]
# ## **D = ~1.9**

# %%
target_D0 = 1.9
f_name = f'mountain_profile_example_D0_{target_D0}.png'
D = 2.3

generated_fractal = None
attempts = 0

while generated_fractal is None and attempts < 100:

    meshmap = midpoint_displacement(iterations, P=P, D=D)
    scalemap = prepare_scalemap(meshmap)
    threshmap, bwratio = thresh(scalemap, iterations)
    coastline = edgedetector(threshmap).astype(np.uint8)
    mountain_slice, mountain_trace = mountainpro(scalemap, iterations, zslice, scale_factor=2)
    generated_fractal = portfolio_plot(mountain_trace, min_size, max_size, num_sizes, num_pos, (21,7), save_dir, f_name, target_D0)
    
    attempts += 1
# Out:
# Skipping, d0 = 1.87, r2 = 0.999520
